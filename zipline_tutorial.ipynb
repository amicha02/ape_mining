# %% [markdown]
# # Zipline Tutorial local backtesting and finance with Python p.1

# %%
# %load_ext zipline
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %% [markdown]
# This is a simple buy Apple shares strategy.

# %%
from zipline.api import order, record, symbol
def initialize(context):
    pass
def handle_data(context, data):
    order(symbol('AAPL'), 10)
    record(AAPL=data.current(symbol('AAPL'), 'price'))

# %% [markdown]
# This is the performance output.

# %%
# %zipline --bundle quandl --start 2000-1-1 --end 2012-1-1 -o backtest.pickle --no-benchmark
# Out:
#                                         period_open              period_close  \
# 2000-01-03 21:00:00+00:00 2000-01-03 14:31:00+00:00 2000-01-03 21:00:00+00:00
# 2000-01-04 21:00:00+00:00 2000-01-04 14:31:00+00:00 2000-01-04 21:00:00+00:00
# 2000-01-05 21:00:00+00:00 2000-01-05 14:31:00+00:00 2000-01-05 21:00:00+00:00
# 2000-01-06 21:00:00+00:00 2000-01-06 14:31:00+00:00 2000-01-06 21:00:00+00:00
# 2000-01-07 21:00:00+00:00 2000-01-07 14:31:00+00:00 2000-01-07 21:00:00+00:00
# ...                                             ...                       ...
# 2011-12-23 21:00:00+00:00 2011-12-23 14:31:00+00:00 2011-12-23 21:00:00+00:00
# 2011-12-27 21:00:00+00:00 2011-12-27 14:31:00+00:00 2011-12-27 21:00:00+00:00
# 2011-12-28 21:00:00+00:00 2011-12-28 14:31:00+00:00 2011-12-28 21:00:00+00:00
# 2011-12-29 21:00:00+00:00 2011-12-29 14:31:00+00:00 2011-12-29 21:00:00+00:00
# 2011-12-30 21:00:00+00:00 2011-12-30 14:31:00+00:00 2011-12-30 21:00:00+00:00
#
#                            starting_cash   ending_cash       returns  \
# 2000-01-03 21:00:00+00:00   1.000000e+07  1.000000e+07  0.000000e+00
# 2000-01-04 21:00:00+00:00   1.000000e+07  9.998974e+06 -5.225000e-08
# 2000-01-05 21:00:00+00:00   9.998974e+06  9.997934e+06  1.447000e-06
# 2000-01-06 21:00:00+00:00   9.997934e+06  9.996983e+06 -1.804847e-05
# 2000-01-07 21:00:00+00:00   9.996983e+06  9.995988e+06  1.344947e-05
# ...                                  ...           ...           ...
# 2011-12-23 21:00:00+00:00   6.670173e+06  6.666138e+06  8.764560e-03
# 2011-12-27 21:00:00+00:00   6.666138e+06  6.662071e+06  5.817762e-03
# 2011-12-28 21:00:00+00:00   6.662071e+06  6.658042e+06 -7.033037e-03
# 2011-12-29 21:00:00+00:00   6.658042e+06  6.653989e+06  4.516405e-03
# 2011-12-30 21:00:00+00:00   6.653989e+06  6.649937e+06 -2.176861e-04
#
#                            portfolio_value  longs_count  shorts_count  \
# 2000-01-03 21:00:00+00:00     1.000000e+07            0             0
# 2000-01-04 21:00:00+00:00     9.999999e+06            1             0
# 2000-01-05 21:00:00+00:00     1.000001e+07            1             0
# 2000-01-06 21:00:00+00:00     9.999833e+06            1             0
# 2000-01-07 21:00:00+00:00     9.999968e+06            1             0
# ...                                    ...          ...           ...
# 2011-12-23 21:00:00+00:00     2.499345e+07            1             0
# 2011-12-27 21:00:00+00:00     2.513886e+07            1             0
# 2011-12-28 21:00:00+00:00     2.496206e+07            1             0
# 2011-12-29 21:00:00+00:00     2.507480e+07            1             0
# 2011-12-30 21:00:00+00:00     2.506934e+07            1             0
#
#                            long_value  short_value  ...  algo_volatility  \
# 2000-01-03 21:00:00+00:00         0.0          0.0  ...              NaN
# 2000-01-04 21:00:00+00:00      1025.0          0.0  ...     5.865048e-07
# 2000-01-05 21:00:00+00:00      2080.0          0.0  ...     1.350778e-05
# 2000-01-06 21:00:00+00:00      2850.0          0.0  ...     1.473588e-04
# 2000-01-07 21:00:00+00:00      3980.0          0.0  ...     1.786638e-04
# ...                               ...          ...  ...              ...
# 2011-12-23 21:00:00+00:00  18327315.2          0.0  ...     1.067034e-01
# 2011-12-27 21:00:00+00:00  18476788.5          0.0  ...     1.066975e-01
# 2011-12-28 21:00:00+00:00  18304014.4          0.0  ...     1.067010e-01
# 2011-12-29 21:00:00+00:00  18420806.4          0.0  ...     1.066902e-01
# 2011-12-30 21:00:00+00:00  18419400.0          0.0  ...     1.066727e-01
#
#                            benchmark_period_return  benchmark_volatility  \
# 2000-01-03 21:00:00+00:00                      0.0                   NaN
# 2000-01-04 21:00:00+00:00                      0.0                   0.0
# 2000-01-05 21:00:00+00:00                      0.0                   0.0
# 2000-01-06 21:00:00+00:00                      0.0                   0.0
# 2000-01-07 21:00:00+00:00                      0.0                   0.0
# ...                                            ...                   ...
# 2011-12-23 21:00:00+00:00                      0.0                   0.0
# 2011-12-27 21:00:00+00:00                      0.0                   0.0
# 2011-12-28 21:00:00+00:00                      0.0                   0.0
# 2011-12-29 21:00:00+00:00                      0.0                   0.0
# 2011-12-30 21:00:00+00:00                      0.0                   0.0
#
#                            alpha  beta     sharpe     sortino  max_drawdown  \
# 2000-01-03 21:00:00+00:00   None  None        NaN         NaN  0.000000e+00
# 2000-01-04 21:00:00+00:00   None  None -11.224972  -11.224972 -5.225000e-08
# 2000-01-05 21:00:00+00:00   None  None   8.673445  244.652548 -5.225000e-08
# 2000-01-06 21:00:00+00:00   None  None  -7.119932   -7.323848 -1.804847e-05
# 2000-01-07 21:00:00+00:00   None  None  -0.903900   -1.260374 -1.804847e-05
# ...                          ...   ...        ...         ...           ...
# 2011-12-23 21:00:00+00:00   None  None   0.771027    1.120816 -2.787769e-01
# 2011-12-27 21:00:00+00:00   None  None   0.775370    1.127253 -2.787769e-01
# 2011-12-28 21:00:00+00:00   None  None   0.769582    1.118632 -2.787769e-01
# 2011-12-29 21:00:00+00:00   None  None   0.772940    1.123585 -2.787769e-01
# 2011-12-30 21:00:00+00:00   None  None   0.772640    1.123150 -2.787769e-01
#
#                            max_leverage  excess_return
# 2000-01-03 21:00:00+00:00      0.000000            0.0
# 2000-01-04 21:00:00+00:00      0.000103            0.0
# 2000-01-05 21:00:00+00:00      0.000208            0.0
# 2000-01-06 21:00:00+00:00      0.000285            0.0
# 2000-01-07 21:00:00+00:00      0.000398            0.0
# ...                                 ...            ...
# 2011-12-23 21:00:00+00:00      0.734905            0.0
# 2011-12-27 21:00:00+00:00      0.734989            0.0
# 2011-12-28 21:00:00+00:00      0.734989            0.0
# 2011-12-29 21:00:00+00:00      0.734989            0.0
# 2011-12-30 21:00:00+00:00      0.734989            0.0
#
# [3019 rows x 38 columns]

# %% [markdown]
# There are many things you can do with this dataframe, like visualizing it for inference.
# # Visualizing Strategy Metrics

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
backtest_df = pd.read_pickle('backtest.pickle')
backtest_df.portfolio_value.plot()
# Out:
# <AxesSubplot:>

# %%
# Testing pushing changes to amicha branch..
