# %% [markdown]
# # Pipeline Testing

# %%
#
import os
import numpy as np
import pandas as pd
from pandas import Timestamp
import seaborn as sns
import matplotlib.pyplot as plt

#
from zipline.api import order_target_percent, record, symbol, set_benchmark, get_open_orders
import zipline
import datetime
import pytz
from zipline.data.bundles import load
from trading_calendars import get_calendar
import pyfolio as pf
#
# %load_ext zipline
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %% [markdown]
# ## Check Symbols of Bundle

# %%
now = Timestamp.utcnow()
bundle = load('NFTU', os.environ, now)
symbols = set(str(asset.symbol) 
              for asset in bundle.asset_finder.retrieve_all(
                           bundle.asset_finder.equities_sids))

print(symbols)
# Out:
# {'AVAX', 'SOL', 'MATIC', 'ADA', 'TFUEL', 'MANA', 'FLOW'}

# %% [markdown]
# ## Simple Strategy

# %%
selected_coin = 'ADA'
shortest_period = 7
longest_period = 14
holding_period = 2

def initialize(context):
    context.i = 0
    context.holding_days = 0
    context.bought = False
    set_benchmark(symbol(selected_coin))
    context.asset = symbol(selected_coin)

def handle_data(context, data):
    # skip days for moving average
    context.i += 1
    if context.i < longest_period:
        return
    if context.bought:
        context.holding_days += 1
        
    # trading algorithm
    short_ma = data.history(context.asset, 'close', bar_count=shortest_period, frequency='1d').mean()
    long_ma = data.history(context.asset, 'close', bar_count=longest_period, frequency='1d').mean()

    open_orders = get_open_orders()
    
    # buy signal
    if context.asset not in open_orders:
        if short_ma > long_ma and context.holding_days == 0 and not context.bought:
            order_target_percent(context.asset, 1.0)
            context.bought = True
        
    # sell signal
    if (short_ma < long_ma or context.holding_days == holding_period) and context.bought:
        order_target_percent(context.asset, 0.0)
        context.holding_days = 0
        context.bought = False

    # record price
    record(close=data.current(symbol(selected_coin), 'close'),
          short_ma=short_ma,
          long_ma=long_ma)

# %%
# date range MUST BE pd.Timestamp
start_date = pd.Timestamp('2017-11-09', tz='utc')
end_date = pd.Timestamp('2022-04-11', tz='utc')

# performance of algorithm once run
perf = zipline.run_algorithm(start=start_date,
                            end=end_date,
                            trading_calendar=get_calendar('24/7'),
                            initialize=initialize,
                            capital_base=40000,
                            handle_data=handle_data,
                            bundle='NFTU',
                            data_frequency='daily')
perf.head()
perf.tail()
# Out:
# C:\Users\Michael\anaconda3\envs\ml4t\lib\site-packages\empyrical\stats.py:710: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(
# C:\Users\Michael\anaconda3\envs\ml4t\lib\site-packages\empyrical\stats.py:799: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(average_annual_return, annualized_downside_risk, out=out)
#                                         period_open              period_close  \
# 2022-04-07 23:59:00+00:00 2022-04-07 00:00:00+00:00 2022-04-07 23:59:00+00:00
# 2022-04-08 23:59:00+00:00 2022-04-08 00:00:00+00:00 2022-04-08 23:59:00+00:00
# 2022-04-09 23:59:00+00:00 2022-04-09 00:00:00+00:00 2022-04-09 23:59:00+00:00
# 2022-04-10 23:59:00+00:00 2022-04-10 00:00:00+00:00 2022-04-10 23:59:00+00:00
# 2022-04-11 23:59:00+00:00 2022-04-11 00:00:00+00:00 2022-04-11 23:59:00+00:00
#
#                            ending_cash  portfolio_value  longs_count  \
# 2022-04-07 23:59:00+00:00    521.92199        521.92199            0
# 2022-04-08 23:59:00+00:00    521.92199        521.92199            0
# 2022-04-09 23:59:00+00:00    521.92199        521.92199            0
# 2022-04-10 23:59:00+00:00    521.92199        521.92199            0
# 2022-04-11 23:59:00+00:00    521.92199        521.92199            0
#
#                            shorts_count  long_value  short_value  \
# 2022-04-07 23:59:00+00:00             0         0.0          0.0
# 2022-04-08 23:59:00+00:00             0         0.0          0.0
# 2022-04-09 23:59:00+00:00             0         0.0          0.0
# 2022-04-10 23:59:00+00:00             0         0.0          0.0
# 2022-04-11 23:59:00+00:00             0         0.0          0.0
#
#                            long_exposure  pnl  ...      beta    sharpe  \
# 2022-04-07 23:59:00+00:00            0.0  0.0  ...  0.516676 -0.366648
# 2022-04-08 23:59:00+00:00            0.0  0.0  ...  0.516446 -0.366534
# 2022-04-09 23:59:00+00:00            0.0  0.0  ...  0.516439 -0.366421
# 2022-04-10 23:59:00+00:00            0.0  0.0  ...  0.516419 -0.366307
# 2022-04-11 23:59:00+00:00            0.0  0.0  ...  0.515900 -0.366194
#
#                             sortino max_drawdown  max_leverage excess_return  \
# 2022-04-07 23:59:00+00:00 -0.872824    -0.998565      2.577775           0.0
# 2022-04-08 23:59:00+00:00 -0.872553    -0.998565      2.577775           0.0
# 2022-04-09 23:59:00+00:00 -0.872283    -0.998565      2.577775           0.0
# 2022-04-10 23:59:00+00:00 -0.872012    -0.998565      2.577775           0.0
# 2022-04-11 23:59:00+00:00 -0.871742    -0.998565      2.577775           0.0
#
#                            treasury_period_return  close  short_ma   long_ma
# 2022-04-07 23:59:00+00:00                     0.0  1.092  1.148000  1.154286
# 2022-04-08 23:59:00+00:00                     0.0  1.026  1.128143  1.149143
# 2022-04-09 23:59:00+00:00                     0.0  1.045  1.112286  1.141571
# 2022-04-10 23:59:00+00:00                     0.0  1.031  1.090143  1.130786
# 2022-04-11 23:59:00+00:00                     0.0  0.934  1.050286  1.113929
#
# [5 rows x 40 columns]

# %%
# Extract algo returns and benchmark returns
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
benchmark_period_return = perf['benchmark_period_return']

# Convert benchmark returns to daily returns
#daily_returns = (1 + benchmark_period_return) / (1 + benchmark_period_return.shift()) - 1
daily_benchmark_returns = np.exp(np.log(benchmark_period_return + 1.0).diff()) - 1

# Create tear sheet
pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, benchmark_rets=daily_benchmark_returns, live_start_date='2021-01-27')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2017-11-09</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2022-04-11</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>55</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>20</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-55.523%</td>
#       <td>-27.498%</td>
#       <td>-49.189%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-97.712%</td>
#       <td>-42.962%</td>
#       <td>-98.695%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>109.718%</td>
#       <td>48.333%</td>
#       <td>96.913%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.37</td>
#       <td>-0.43</td>
#       <td>-0.37</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.56</td>
#       <td>-0.39</td>
#       <td>-0.49</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.92</td>
#       <td>0.09</td>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-99.753%</td>
#       <td>-70.627%</td>
#       <td>-99.856%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.85</td>
#       <td>0.88</td>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-0.95</td>
#       <td>-0.62</td>
#       <td>-0.87</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>16.04</td>
#       <td>0.81</td>
#       <td>16.95</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>386.67</td>
#       <td>12.35</td>
#       <td>462.55</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.79</td>
#       <td>0.71</td>
#       <td>0.80</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-13.986%</td>
#       <td>-6.171%</td>
#       <td>-12.351%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>1.01</td>
#       <td>0.96</td>
#       <td>1.00</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>35.347%</td>
#       <td>27.883%</td>
#       <td>33.421%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.68</td>
#       <td>-0.34</td>
#       <td>-0.62</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.59</td>
#       <td>0.20</td>
#       <td>0.52</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>99.86</td>
#       <td>2018-01-03</td>
#       <td>2022-04-06</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>35.15</td>
#       <td>2017-11-28</td>
#       <td>2017-12-10</td>
#       <td>2017-12-16</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>22.37</td>
#       <td>2017-12-19</td>
#       <td>2017-12-22</td>
#       <td>2017-12-29</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.41</td>
#       <td>2017-11-22</td>
#       <td>2017-11-24</td>
#       <td>2017-11-25</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.25</td>
#       <td>2017-12-17</td>
#       <td>2017-12-18</td>
#       <td>2017-12-19</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\Michael\anaconda3\envs\ml4t\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 74.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Michael\anaconda3\envs\ml4t\lib\site-packages\pandas\core\indexes\base.py:5278: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.14%</td>
#       <td>-28.78%</td>
#       <td>177.46%</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\Michael\anaconda3\envs\ml4t\lib\site-packages\pandas\core\indexes\base.py:5278: FutureWarning: Indexing a timezone-aware DatetimeIndex with a timezone-naive datetime is deprecated and will raise KeyError in a future version.  Use a timezone-aware object instead.
#   start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ADA</th>
#       <td>257.78%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ADA</th>
#       <td>-61.74%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ADA</th>
#       <td>257.78%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Simulation of Sentiment Data

# %% [markdown]
# One of the NFT signals we will be looking at first is sentiment data from messages about NFTs and/or the specific chains of the coins of our universe. We can start simply by assuming that text data will be assigned a 0 if it has negative sentiment, and a 1 if it has positive sentiment. Then, for trading purposes we will simulate the overall sentiment of each day with a 0 or 1.

# %%
simulated_sentiment_arr = np.random.randint(0, 2, (end_date - start_date).days+1)
_ = plt.hist(simulated_sentiment_arr)

# %%
selected_coin = 'ADA'
holding_period = 2

def initialize(context):
    context.i = 0
    context.holding_days = 0
    context.bought = False
    set_benchmark(symbol(selected_coin))
    context.asset = symbol(selected_coin)

def handle_data(context, data):
    if context.bought:
        context.holding_days += 1
        
    # trading algorithm

    open_orders = get_open_orders()
    
    # buy signal
    if context.asset not in open_orders:
        if simulated_sentiment_arr[context.i] and context.holding_days == 0 and not context.bought:
            order_target_percent(context.asset, 1.0)
            context.bought = True
        
    # sell signal
    if (not simulated_sentiment_arr[context.i] or context.holding_days == holding_period) and context.bought:
        order_target_percent(context.asset, 0.0)
        context.holding_days = 0
        context.bought = False
        
    context.i += 1
    # record price
    record(close=data.current(symbol(selected_coin), 'close'))

# %%
# date range MUST BE pd.Timestamp
start_date = pd.Timestamp('2017-11-09', tz='utc')
end_date = pd.Timestamp('2022-04-11', tz='utc')

# performance of algorithm once run
perf = zipline.run_algorithm(start=start_date,
                            end=end_date,
                            trading_calendar=get_calendar('24/7'),
                            initialize=initialize,
                            capital_base=40000,
                            handle_data=handle_data,
                            bundle='NFTU',
                            data_frequency='daily')
perf.head()
perf.tail()
# Out:
#                                         period_open              period_close  \
# 2022-04-07 23:59:00+00:00 2022-04-07 00:00:00+00:00 2022-04-07 23:59:00+00:00
# 2022-04-08 23:59:00+00:00 2022-04-08 00:00:00+00:00 2022-04-08 23:59:00+00:00
# 2022-04-09 23:59:00+00:00 2022-04-09 00:00:00+00:00 2022-04-09 23:59:00+00:00
# 2022-04-10 23:59:00+00:00 2022-04-10 00:00:00+00:00 2022-04-10 23:59:00+00:00
# 2022-04-11 23:59:00+00:00 2022-04-11 00:00:00+00:00 2022-04-11 23:59:00+00:00
#
#                            long_value  short_value  long_exposure       pnl  \
# 2022-04-07 23:59:00+00:00       3.276          0.0          3.276 -0.004638
# 2022-04-08 23:59:00+00:00       0.000          0.0          0.000 -0.202539
# 2022-04-09 23:59:00+00:00       3.135          0.0          3.135 -0.004568
# 2022-04-10 23:59:00+00:00       0.000          0.0          0.000 -0.046547
# 2022-04-11 23:59:00+00:00       0.000          0.0          0.000  0.000000
#
#                            short_exposure  capital_used  \
# 2022-04-07 23:59:00+00:00             0.0     -3.280638
# 2022-04-08 23:59:00+00:00             0.0      3.073461
# 2022-04-09 23:59:00+00:00             0.0     -3.139567
# 2022-04-10 23:59:00+00:00             0.0      3.088454
# 2022-04-11 23:59:00+00:00             0.0      0.000000
#
#                                                                       orders  \
# 2022-04-07 23:59:00+00:00  [{'id': '7cc301a228d74ce195e25e8591d1955e', 'd...
# 2022-04-08 23:59:00+00:00  [{'id': '2899a70a830d486d8662b00a86b8e09b', 'd...
# 2022-04-09 23:59:00+00:00  [{'id': '92ed4024ebc1402ea73aab24c4819cae', 'd...
# 2022-04-10 23:59:00+00:00  [{'id': '47688b7639d648b59e231a35aa5e0280', 'd...
# 2022-04-11 23:59:00+00:00                                                 []
#
#                             returns  ...     alpha      beta    sharpe  \
# 2022-04-07 23:59:00+00:00 -0.001350  ... -0.807892  0.359933 -1.560058
# 2022-04-08 23:59:00+00:00 -0.059040  ... -0.808868  0.360134 -1.571046
# 2022-04-09 23:59:00+00:00 -0.001415  ... -0.808914  0.360132 -1.570847
# 2022-04-10 23:59:00+00:00 -0.014440  ... -0.809007  0.360138 -1.573296
# 2022-04-11 23:59:00+00:00  0.000000  ... -0.807695  0.359739 -1.572804
#
#                             sortino  max_drawdown  max_leverage  \
# 2022-04-07 23:59:00+00:00 -2.451615     -0.999985      1.659663
# 2022-04-08 23:59:00+00:00 -2.467012     -0.999985      1.659663
# 2022-04-09 23:59:00+00:00 -2.466700     -0.999985      1.659663
# 2022-04-10 23:59:00+00:00 -2.470405     -0.999985      1.659663
# 2022-04-11 23:59:00+00:00 -2.469641     -0.999985      1.659663
#
#                            excess_return  treasury_period_return  \
# 2022-04-07 23:59:00+00:00            0.0                     0.0
# 2022-04-08 23:59:00+00:00            0.0                     0.0
# 2022-04-09 23:59:00+00:00            0.0                     0.0
# 2022-04-10 23:59:00+00:00            0.0                     0.0
# 2022-04-11 23:59:00+00:00            0.0                     0.0
#
#                            trading_days  period_label
# 2022-04-07 23:59:00+00:00          1611       2022-04
# 2022-04-08 23:59:00+00:00          1612       2022-04
# 2022-04-09 23:59:00+00:00          1613       2022-04
# 2022-04-10 23:59:00+00:00          1614       2022-04
# 2022-04-11 23:59:00+00:00          1615       2022-04
#
# [5 rows x 38 columns]

# %%
# Extract algo returns and benchmark returns
returns, positions, transactions = pf.utils.extract_rets_pos_txn_from_zipline(perf)
benchmark_period_return = perf['benchmark_period_return']

# Convert benchmark returns to daily returns
#daily_returns = (1 + benchmark_period_return) / (1 + benchmark_period_return.shift()) - 1
daily_benchmark_returns = np.exp(np.log(benchmark_period_return + 1.0).diff()) - 1

# Create tear sheet
pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, benchmark_rets=daily_benchmark_returns, live_start_date='2022-01-01')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=4>2017-11-09</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=4>2022-04-11</td></tr>
#     <tr style="text-align: right;"><th>In-sample months</th><td colspan=4>72</td></tr>
#     <tr style="text-align: right;"><th>Out-of-sample months</th><td colspan=4>4</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>In-sample</th>
#       <th>Out-of-sample</th>
#       <th>All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-78.511%</td>
#       <td>-39.716%</td>
#       <td>-77.079%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-99.99%</td>
#       <td>-18.359%</td>
#       <td>-99.992%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>77.823%</td>
#       <td>47.301%</td>
#       <td>76.274%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-1.61</td>
#       <td>-0.83</td>
#       <td>-1.57</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.79</td>
#       <td>-1.09</td>
#       <td>-0.77</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.88</td>
#       <td>0.51</td>
#       <td>0.86</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-99.998%</td>
#       <td>-36.341%</td>
#       <td>-99.998%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.65</td>
#       <td>0.82</td>
#       <td>0.66</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-2.54</td>
#       <td>-1.11</td>
#       <td>-2.47</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>4.16</td>
#       <td>-0.25</td>
#       <td>4.13</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>64.24</td>
#       <td>2.41</td>
#       <td>65.28</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.76</td>
#       <td>0.81</td>
#       <td>0.77</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-10.302%</td>
#       <td>-6.116%</td>
#       <td>-10.086%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.96</td>
#       <td>0.87</td>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>38.094%</td>
#       <td>37.985%</td>
#       <td>38.087%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.82</td>
#       <td>-0.14</td>
#       <td>-0.81</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.36</td>
#       <td>0.44</td>
#       <td>0.36</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>100.00</td>
#       <td>2018-01-03</td>
#       <td>2020-11-20</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>30.63</td>
#       <td>2017-12-14</td>
#       <td>2017-12-24</td>
#       <td>2018-01-03</td>
#       <td>15</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>25.51</td>
#       <td>2017-11-30</td>
#       <td>2017-12-11</td>
#       <td>2017-12-14</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>21.32</td>
#       <td>2017-11-09</td>
#       <td>2017-11-26</td>
#       <td>2017-11-27</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axis.py:1506, in Axis.convert_units(self, x)
#    1505 try:
# -> 1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
#
# File ~\anaconda3\envs\ml4t\lib\site-packages\pandas\plotting\_matplotlib\converter.py:210, in PeriodConverter.convert(values, units, axis)
#     209 else:
# --> 210     values = PeriodConverter._convert_1d(values, units, axis)
#     211 return values
#
# File ~\anaconda3\envs\ml4t\lib\site-packages\pandas\plotting\_matplotlib\converter.py:229, in PeriodConverter._convert_1d(values, units, axis)
#     228 elif isinstance(values, (list, tuple, np.ndarray, Index)):
# --> 229     return [get_datevalue(x, axis.freq) for x in values]
#     230 return values
#
# File ~\anaconda3\envs\ml4t\lib\site-packages\pandas\plotting\_matplotlib\converter.py:229, in <listcomp>(.0)
#     228 elif isinstance(values, (list, tuple, np.ndarray, Index)):
# --> 229     return [get_datevalue(x, axis.freq) for x in values]
#     230 return values
#
# File ~\anaconda3\envs\ml4t\lib\site-packages\pandas\plotting\_matplotlib\converter.py:237, in get_datevalue(date, freq)
#     236 elif isinstance(date, (str, datetime, pydt.date, pydt.time, np.datetime64)):
# --> 237     return Period(date, freq).ordinal
#     238 elif (
#     239     is_integer(date)
#     240     or is_float(date)
#     241     or (isinstance(date, (np.ndarray, Index)) and (date.size == 1))
#     242 ):
#
# AttributeError: 'NaTType' object has no attribute 'ordinal'
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Input In [9], in <cell line: 10>()
#       7 daily_benchmark_returns = np.exp(np.log(benchmark_period_return + 1.0).diff()) - 1
#       9 # Create tear sheet
# ---> 10 pf.create_full_tear_sheet(returns, positions=positions, transactions=transactions, benchmark_rets=daily_benchmark_returns, live_start_date='2022-01-01')
#
# File ~\anaconda3\envs\ml4t\lib\site-packages\pyfolio\tears.py:199, in create_full_tear_sheet(returns, positions, transactions, market_data, benchmark_rets, slippage, live_start_date, sector_mappings, round_trips, estimate_intraday, hide_positions, cone_std, bootstrap, unadjusted_returns, turnover_denom, set_context, factor_returns, factor_loadings, pos_in_dollars, header_rows, factor_partitions)
#     191     returns = txn.adjust_returns_for_slippage(
#     192         returns, positions, transactions, slippage
#     193     )
#     195 positions = utils.check_intraday(
#     196     estimate_intraday, returns, positions, transactions
#     197 )
# --> 199 create_returns_tear_sheet(
#     200     returns,
#     201     positions=positions,
#     202     transactions=transactions,
#     203     live_start_date=live_start_date,
#     204     cone_std=cone_std,
#     205     benchmark_rets=benchmark_rets,
#     206     bootstrap=bootstrap,
#     207     turnover_denom=turnover_denom,
#     208     header_rows=header_rows,
#     209     set_context=set_context,
#     210 )
#     212 create_interesting_times_tear_sheet(
#     213     returns, benchmark_rets=benchmark_rets, set_context=set_context
#     214 )
#     216 if positions is not None:
#
# File ~\anaconda3\envs\ml4t\lib\site-packages\pyfolio\plotting.py:50, in customize.<locals>.call_w_context(*args, **kwargs)
#      48 if set_context:
#      49     with plotting_context(), axes_style():
# ---> 50         return func(*args, **kwargs)
#      51 else:
#      52     return func(*args, **kwargs)
#
# File ~\anaconda3\envs\ml4t\lib\site-packages\pyfolio\tears.py:632, in create_returns_tear_sheet(returns, positions, transactions, live_start_date, cone_std, benchmark_rets, bootstrap, turnover_denom, header_rows, return_fig)
#     629 plotting.plot_rolling_sharpe(returns, ax=ax_rolling_sharpe)
#     631 # Drawdowns
# --> 632 plotting.plot_drawdown_periods(returns, top=5, ax=ax_drawdown)
#     634 plotting.plot_drawdown_underwater(returns=returns, ax=ax_underwater)
#     636 plotting.plot_monthly_returns_heatmap(returns, ax=ax_monthly_heatmap)
#
# File ~\anaconda3\envs\ml4t\lib\site-packages\pyfolio\plotting.py:447, in plot_drawdown_periods(returns, top, ax, **kwargs)
#     445     if pd.isnull(recovery):
#     446         recovery = returns.index[-1]
# --> 447     ax.fill_between(
#     448         (peak, recovery), lim[0], lim[1], alpha=0.4, color=colors[i]
#     449     )
#     450 ax.set_ylim(lim)
#     451 ax.set_title("Top %i drawdown periods" % top)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_axes.py:5206, in Axes.fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5204 def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5205                  step=None, **kwargs):
# -> 5206     return self._fill_between_x_or_y(
#    5207         "x", x, y1, y2,
#    5208         where=where, interpolate=interpolate, step=step, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_axes.py:5112, in Axes._fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5107         kwargs["facecolor"] = \
#    5108             self._get_patches_for_fill.get_next_color()
#    5110 # Handle united data, such as dates
#    5111 ind, dep1, dep2 = map(
# -> 5112     ma.masked_invalid, self._process_unit_info(
#    5113         [(ind_dir, ind), (dep_dir, dep1), (dep_dir, dep2)], kwargs))
#    5115 for name, array in [
#    5116         (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5117     if array.ndim > 1:
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_base.py:2539, in _AxesBase._process_unit_info(self, datasets, kwargs, convert)
#    2537             if dataset_axis_name == axis_name and data is not None:
#    2538                 axis.update_units(data)
# -> 2539 return [axis_map[axis_name].convert_units(data)
#    2540         if convert and data is not None else data
#    2541         for axis_name, data in datasets]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_base.py:2539, in <listcomp>(.0)
#    2537             if dataset_axis_name == axis_name and data is not None:
#    2538                 axis.update_units(data)
# -> 2539 return [axis_map[axis_name].convert_units(data)
#    2540         if convert and data is not None else data
#    2541         for axis_name, data in datasets]
#
# File ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axis.py:1508, in Axis.convert_units(self, x)
#    1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
# -> 1508     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1509                                  f'units: {x!r}') from e
#    1510 return ret
#
# ConversionError: Failed to convert value(s) to axis units: (NaT, Timestamp('2022-04-11 00:00:00+0000', tz='UTC', freq='D'))

# %% [markdown]
# The strategy is not good with just sentiment data alone (and no other strategy), as expected. However, these alternative and quantitative NFT data we will be using could be more effective as features in a regression model aimed to predict returns.

# %% [markdown]
# ## OLS / Regression + Simulated Sentiment Feature

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# 2021-1-28 start
data_path = r"../data/instruments_modified"
instrument_symbols = [fn.split(".")[0] for fn in os.listdir(data_path)]

# Create hierarchical dataframe for universe of instruments?
uni_df = pd.concat([pd.read_csv(os.path.join(data_path,file)) for file in os.listdir(data_path)], keys=instrument_symbols).swaplevel()

# create multiindex
uni_df = uni_df.set_index([[tup[1] for tup in uni_df.index], pd.DatetimeIndex(uni_df['Date'])]).drop("Date", axis=1)
uni_df.index = uni_df.index.rename(("Symbol", "Date"))

# %%
uni_df.loc[pd.IndexSlice[:, "2021-01-28"],:]
# Out:
#                         Open       High        Low      Close        Volume  \
# Symbol Date
# ADA    2021-01-28   0.313344   0.353553   0.307383   0.345811  2.184946e+09
# AVAX   2021-01-28  11.171011  12.668179  10.860486  12.003784  1.096995e+08
# FLOW   2021-01-28   6.936125   7.820695   6.089595   7.183794  1.363120e+07
# MANA   2021-01-28   0.147498   0.164600   0.141742   0.158452  6.148773e+07
# MATIC  2021-01-28   0.042006   0.044492   0.038580   0.038755  1.657363e+08
# SOL    2021-01-28   3.693176   3.936221   3.612791   3.829965  8.383889e+07
# TFUEL  2021-01-28   0.029300   0.031066   0.029058   0.029370  1.171442e+07
#
#                      Market Cap
# Symbol Date
# ADA    2021-01-28  1.053534e+10
# AVAX   2021-01-28  9.095808e+08
# FLOW   2021-01-28  1.641425e+08
# MANA   2021-01-28  2.403431e+08
# MATIC  2021-01-28  2.052327e+08
# SOL    2021-01-28  9.958197e+08
# TFUEL  2021-01-28  1.573075e+08

# %%
uni_prices = uni_df.loc[pd.IndexSlice[:, "2021-01-28":],:]
uni_prices
# Out:
#                        Open      High       Low     Close        Volume  \
# Symbol Date
# ADA    2021-01-28  0.313344  0.353553  0.307383  0.345811  2.184946e+09
#        2021-01-29  0.344875  0.366880  0.333606  0.348897  2.551364e+09
#        2021-01-30  0.347677  0.373706  0.337399  0.362755  2.122323e+09
#        2021-01-31  0.363138  0.375969  0.338765  0.346010  2.230496e+09
#        2021-02-01  0.345495  0.418427  0.334615  0.402698  1.944434e+09
# ...                     ...       ...       ...       ...           ...
# TFUEL  2022-04-13  0.164733  0.172376  0.163245  0.169795  2.146501e+07
#        2022-04-14  0.169287  0.170751  0.160710  0.163625  2.503801e+07
#        2022-04-15  0.163616  0.167434  0.163308  0.167315  2.003002e+07
#        2022-04-16  0.167315  0.167884  0.162870  0.165885  1.721647e+07
#        2022-04-17  0.165885  0.167502  0.161584  0.161584  1.854334e+07
#
#                      Market Cap
# Symbol Date
# ADA    2021-01-28  1.053534e+10
#        2021-01-29  1.108232e+10
#        2021-01-30  1.101091e+10
#        2021-01-31  1.110253e+10
#        2021-02-01  1.118967e+10
# ...                         ...
# TFUEL  2022-04-13  8.879270e+08
#        2022-04-14  8.824291e+08
#        2022-04-15  8.769784e+08
#        2022-04-16  8.795143e+08
#        2022-04-17  8.772434e+08
#
# [3115 rows x 6 columns]

# %% [markdown]
# ### Computing Lagged Returns for Predictive Modeling

# %%
lags = (1, 2, 3, 4, 5, 6, 7, 14, 28)

# %%
# Chapter 6 nb
returns = uni_prices.groupby(level='Symbol').Close.pct_change()
percentiles=[.0001, .001, .01]
percentiles+= [1-p for p in percentiles]
returns.describe(percentiles=percentiles).iloc[2:].to_frame('percentiles').style.format(lambda x: f'{x:,.2%}')
# Out:
# <style  type="text/css" >
# </style><table id="T_4954b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >percentiles</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4954b_level0_row0" class="row_heading level0 row0" >std</th>
#                         <td id="T_4954b_row0_col0" class="data row0 col0" >8.41%</td>
#             </tr>
#             <tr>
#                         <th id="T_4954b_level0_row1" class="row_heading level0 row1" >min</th>
#                         <td id="T_4954b_row1_col0" class="data row1 col0" >-36.65%</td>
#             </tr>
#             <tr>
#                         <th id="T_4954b_level0_row2" class="row_heading level0 row2" >0.01%</th>
#                         <td id="T_4954b_row2_col0" class="data row2 col0" >-36.54%</td>
#             </tr>
#             <tr>
#                         <th id="T_4954b_level0_row3" class="row_heading level0 row3" >0.1%</th>
#                         <td id="T_4954b_row3_col0" class="data row3 col0" >-29.87%</td>
#             </tr>
#             <tr>
#                         <th id="T_4954b_level0_row4" class="row_heading level0 row4" >1%</th>
#                         <td id="T_4954b_row4_col0" class="data row4 col0" >-16.36%</td>
#             </tr>
#             <tr>
#                         <th id="T_4954b_level0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_4954b_row5_col0" class="data row5 col0" >0.18%</td>
#             </tr>
#             <tr>
#                         <th id="T_4954b_level0_row6" class="row_heading level0 row6" >99%</th>
#                         <td id="T_4954b_row6_col0" class="data row6 col0" >27.56%</td>
#             </tr>
#             <tr>
#                         <th id="T_4954b_level0_row7" class="row_heading level0 row7" >99.9%</th>
#                         <td id="T_4954b_row7_col0" class="data row7 col0" >53.49%</td>
#             </tr>
#             <tr>
#                         <th id="T_4954b_level0_row8" class="row_heading level0 row8" >99.99%</th>
#                         <td id="T_4954b_row8_col0" class="data row8 col0" >128.75%</td>
#             </tr>
#             <tr>
#                         <th id="T_4954b_level0_row9" class="row_heading level0 row9" >max</th>
#                         <td id="T_4954b_row9_col0" class="data row9 col0" >153.23%</td>
#             </tr>
#     </tbody></table>

# %%
# Chapter 6 nb
q = 0.0001

for lag in lags:
    uni_prices[f'return_{lag}d'] = (uni_prices.groupby(level='Symbol').Close
                                .pct_change(lag)
                                .pipe(lambda x: x.clip(lower=x.quantile(q),
                                                       upper=x.quantile(1 - q)))
                                .add(1)
                                .pow(1 / lag)
                                .sub(1)
                                )
# Out:
# C:\Users\Michael\AppData\Local\Temp\tmpfhmmuiyd\ipykernel_5908\2750997518.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uni_prices[f'return_{lag}d'] = (uni_prices.groupby(level='Symbol').Close

# %% [markdown]
# ### Shift Lagged Returns

# %%
# Chapter 6 nb
for t in range(len(lags)):
    for lag in lags:
        uni_prices[f'return_{lag}d_lag{t}'] = (uni_prices.groupby(level='Symbol')
                                           [f'return_{lag}d'].shift(t * lag))
# Out:
# C:\Users\Michael\AppData\Local\Temp\tmpfhmmuiyd\ipykernel_5908\4018610045.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uni_prices[f'return_{lag}d_lag{t}'] = (uni_prices.groupby(level='Symbol')

# %%
# Chapter 6 nb

# %%
uni_prices
# Out:
#                        Open      High       Low     Close        Volume  \
# Symbol Date
# ADA    2021-01-28  0.313344  0.353553  0.307383  0.345811  2.184946e+09
#        2021-01-29  0.344875  0.366880  0.333606  0.348897  2.551364e+09
#        2021-01-30  0.347677  0.373706  0.337399  0.362755  2.122323e+09
#        2021-01-31  0.363138  0.375969  0.338765  0.346010  2.230496e+09
#        2021-02-01  0.345495  0.418427  0.334615  0.402698  1.944434e+09
# ...                     ...       ...       ...       ...           ...
# TFUEL  2022-04-13  0.164733  0.172376  0.163245  0.169795  2.146501e+07
#        2022-04-14  0.169287  0.170751  0.160710  0.163625  2.503801e+07
#        2022-04-15  0.163616  0.167434  0.163308  0.167315  2.003002e+07
#        2022-04-16  0.167315  0.167884  0.162870  0.165885  1.721647e+07
#        2022-04-17  0.165885  0.167502  0.161584  0.161584  1.854334e+07
#
#                      Market Cap  return_1d  return_2d  return_3d  return_4d  \
# Symbol Date
# ADA    2021-01-28  1.053534e+10        NaN        NaN        NaN        NaN
#        2021-01-29  1.108232e+10   0.008925        NaN        NaN        NaN
#        2021-01-30  1.101091e+10   0.039719   0.024206        NaN        NaN
#        2021-01-31  1.110253e+10  -0.046159  -0.004146   0.000192        NaN
#        2021-02-01  1.118967e+10   0.163833   0.053618   0.048964   0.038808
# ...                         ...        ...        ...        ...        ...
# TFUEL  2022-04-13  8.879270e+08   0.030727   0.033549  -0.022221  -0.016712
#        2022-04-14  8.824291e+08  -0.036339  -0.003370   0.009707  -0.025769
#        2022-04-15  8.769784e+08   0.022551  -0.007330   0.005197   0.012903
#        2022-04-16  8.795143e+08  -0.008548   0.006881  -0.007736   0.001743
#        2022-04-17  8.772434e+08  -0.025923  -0.017274  -0.004174  -0.012315
#
#                    ...  return_28d_lag7  return_1d_lag8  return_2d_lag8  \
# Symbol Date        ...
# ADA    2021-01-28  ...              NaN             NaN             NaN
#        2021-01-29  ...              NaN             NaN             NaN
#        2021-01-30  ...              NaN             NaN             NaN
#        2021-01-31  ...              NaN             NaN             NaN
#        2021-02-01  ...              NaN             NaN             NaN
# ...                ...              ...             ...             ...
# TFUEL  2022-04-13  ...        -0.010592       -0.029597        0.020720
#        2022-04-14  ...        -0.009830       -0.095886       -0.000047
#        2022-04-15  ...        -0.008499        0.048127        0.013545
#        2022-04-16  ...        -0.007934       -0.056928        0.036967
#        2022-04-17  ...        -0.009678        0.037932        0.038544
#
#                    return_3d_lag8  return_4d_lag8  return_5d_lag8  \
# Symbol Date
# ADA    2021-01-28             NaN             NaN             NaN
#        2021-01-29             NaN             NaN             NaN
#        2021-01-30             NaN             NaN             NaN
#        2021-01-31             NaN             NaN             NaN
#        2021-02-01             NaN             NaN             NaN
# ...                           ...             ...             ...
# TFUEL  2022-04-13        0.000124        0.018141       -0.011045
#        2022-04-14       -0.004172       -0.003640       -0.026619
#        2022-04-15       -0.004121        0.010077       -0.037054
#        2022-04-16        0.014987        0.005564       -0.034325
#        2022-04-17        0.023469        0.000422       -0.019126
#
#                    return_6d_lag8  return_7d_lag8  return_14d_lag8  \
# Symbol Date
# ADA    2021-01-28             NaN             NaN              NaN
#        2021-01-29             NaN             NaN              NaN
#        2021-01-30             NaN             NaN              NaN
#        2021-01-31             NaN             NaN              NaN
#        2021-02-01             NaN             NaN              NaN
# ...                           ...             ...              ...
# TFUEL  2022-04-13       -0.034882        0.006157        -0.014427
#        2022-04-14       -0.021900       -0.012563        -0.002053
#        2022-04-15       -0.013134       -0.005498        -0.004054
#        2022-04-16       -0.001664       -0.006141        -0.003808
#        2022-04-17        0.012909       -0.011104         0.000722
#
#                    return_28d_lag8
# Symbol Date
# ADA    2021-01-28              NaN
#        2021-01-29              NaN
#        2021-01-30              NaN
#        2021-01-31              NaN
#        2021-02-01              NaN
# ...                            ...
# TFUEL  2022-04-13         0.003949
#        2022-04-14         0.002558
#        2022-04-15         0.005821
#        2022-04-16         0.006939
#        2022-04-17         0.011012
#
# [3115 rows x 96 columns]

# %%
uni_prices.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap', 'return_1d',
#        'return_2d', 'return_3d', 'return_4d', 'return_5d', 'return_6d',
#        'return_7d', 'return_14d', 'return_28d', 'return_1d_lag0',
#        'return_2d_lag0', 'return_3d_lag0', 'return_4d_lag0', 'return_5d_lag0',
#        'return_6d_lag0', 'return_7d_lag0', 'return_14d_lag0',
#        'return_28d_lag0', 'return_1d_lag1', 'return_2d_lag1', 'return_3d_lag1',
#        'return_4d_lag1', 'return_5d_lag1', 'return_6d_lag1', 'return_7d_lag1',
#        'return_14d_lag1', 'return_28d_lag1', 'return_1d_lag2',
#        'return_2d_lag2', 'return_3d_lag2', 'return_4d_lag2', 'return_5d_lag2',
#        'return_6d_lag2', 'return_7d_lag2', 'return_14d_lag2',
#        'return_28d_lag2', 'return_1d_lag3', 'return_2d_lag3', 'return_3d_lag3',
#        'return_4d_lag3', 'return_5d_lag3', 'return_6d_lag3', 'return_7d_lag3',
#        'return_14d_lag3', 'return_28d_lag3', 'return_1d_lag4',
#        'return_2d_lag4', 'return_3d_lag4', 'return_4d_lag4', 'return_5d_lag4',
#        'return_6d_lag4', 'return_7d_lag4', 'return_14d_lag4',
#        'return_28d_lag4', 'return_1d_lag5', 'return_2d_lag5', 'return_3d_lag5',
#        'return_4d_lag5', 'return_5d_lag5', 'return_6d_lag5', 'return_7d_lag5',
#        'return_14d_lag5', 'return_28d_lag5', 'return_1d_lag6',
#        'return_2d_lag6', 'return_3d_lag6', 'return_4d_lag6', 'return_5d_lag6',
#        'return_6d_lag6', 'return_7d_lag6', 'return_14d_lag6',
#        'return_28d_lag6', 'return_1d_lag7', 'return_2d_lag7', 'return_3d_lag7',
#        'return_4d_lag7', 'return_5d_lag7', 'return_6d_lag7', 'return_7d_lag7',
#        'return_14d_lag7', 'return_28d_lag7', 'return_1d_lag8',
#        'return_2d_lag8', 'return_3d_lag8', 'return_4d_lag8', 'return_5d_lag8',
#        'return_6d_lag8', 'return_7d_lag8', 'return_14d_lag8',
#        'return_28d_lag8'],
#       dtype='object')

# %% [markdown]
# ### Linear Regression Model

# %%
# Machine Learning for Algorithmic Trading Chapter 6
class MultipleTimeSeriesCV:
    """Generates tuples of train_idx, test_idx pairs
    Assumes the MultiIndex contains levels 'symbol' and 'date'
    purges overlapping outcomes"""

    def __init__(self,
                 n_splits=3,
                 train_period_length=126,
                 test_period_length=21,
                 lookahead=None,
                 date_idx='date',
                 shuffle=False):
        self.n_splits = n_splits
        self.lookahead = lookahead
        self.test_length = test_period_length
        self.train_length = train_period_length
        self.shuffle = shuffle
        self.date_idx = date_idx

    def split(self, X, y=None, groups=None):
        unique_dates = X.index.get_level_values(self.date_idx).unique()
        days = sorted(unique_dates, reverse=True)
        split_idx = []
        for i in range(self.n_splits):
            test_end_idx = i * self.test_length
            test_start_idx = test_end_idx + self.test_length
            train_end_idx = test_start_idx + self.lookahead - 1
            train_start_idx = train_end_idx + self.train_length + self.lookahead - 1
            split_idx.append([train_start_idx, train_end_idx,
                              test_start_idx, test_end_idx])

        dates = X.reset_index()[[self.date_idx]]
        for train_start, train_end, test_start, test_end in split_idx:

            train_idx = dates[(dates[self.date_idx] > days[train_start])
                              & (dates[self.date_idx] <= days[train_end])].index
            test_idx = dates[(dates[self.date_idx] > days[test_start])
                             & (dates[self.date_idx] <= days[test_end])].index
            if self.shuffle:
                np.random.shuffle(list(train_idx))
            yield train_idx.to_numpy(), test_idx.to_numpy()

    def get_n_splits(self, X, y, groups=None):
        return self.n_splits

# %%
X = uni_df

# %%
MONTH = 12
YEAR = 12 * MONTH
train_period_length = 63
test_period_length = 10
n_splits = int(3 * YEAR/test_period_length)
lookahead =1

# cross-validation
cv = MultipleTimeSeriesCV(n_splits=n_splits,
    test_period_length=test_period_length,
    lookahead=lookahead,
    train_period_length=train_period_length)
